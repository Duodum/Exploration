# %% [markdown]
# # Exp 08. 뉴스 요약봇 만들기

# %% [markdown]
# ### 1) 라이브러리 및 데이터 불러오기

# %%
import nltk
nltk.download('stopwords')

import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import AdditiveAttention
import urllib.request
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='bs4')
# Out:
# [nltk_data] Downloading package stopwords to /aiffel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/sunnysai12345/News_Summary/master/news_summary_more.csv", filename="news_summary_more.csv")
data = pd.read_csv('news_summary_more.csv', encoding='iso-8859-1')

# %%
data.sample(10)
# Out:
#                                                headlines  \
# 34953  Sacked AAP advisor sends Ã¢ÂÂ¹2.50-demand dra...
# 24029  Ronaldo given 24-month-long prison sentence, w...
# 39229  Sequel of Kareena Kapoor's 'Veere Di Wedding' ...
# 21668  Usain Bolt demands black car to reach club fro...
# 14255  2 Vyapam scam whistleblowers to contest Madhya...
# 33739  Boxer makes $50 million offer for unified worl...
# 81523  Tesla's newest car Model 3 revealed for the fi...
# 93259  Human ancestors beat HIV-like virus 11 mn year...
# 56510  1st tied Test was caused by direct hit off pen...
# 14962  Twitter users recall Shakti's casting couch af...
#
#                                                     text
# 34953  AAP spokesperson Raghav Chadha has sent a Ã¢Â...
# 24029  Cristiano Ronaldo has been handed a 24-month-l...
# 39229  The spokesperson of Kareena Kapoor Khan and So...
# 21668  Jamaica's eight-time Olympic gold medalist Usa...
# 14255  Two Vyapam scam whistleblowers, namely Dr Anan...
# 33739  WBC heavyweight champion Deontay Wilder has of...
# 81523  Electric carmaker Tesla's Co-founder Elon Musk...
# 93259  In a US-based study, fossils of viruses from H...
# 56510  Australia needed one run off two balls with on...
# 14962  After Shakti Kapoor mocked Tanushree Dutta's a...

# %% [markdown]
# ### 2) 데이터 전처리

# %% [markdown]
# #### 중복, 결측 제거

# %%
print('Headlines 열에서 중복을 배제한 유일한 샘플의 수 :', data['headlines'].nunique())
print('Text 열에서 중복을 배제한 유일한 샘플의 수 :', data['text'].nunique())
# Out:
# Headlines 열에서 중복을 배제한 유일한 샘플의 수 : 98280
# Text 열에서 중복을 배제한 유일한 샘플의 수 : 98360

# %%
data.drop_duplicates(subset = ['text'], inplace = True)
print('전체 샘플 수 :',(len(data)))
# Out:
# 전체 샘플 수 : 98360

# %%
print(data.isnull().sum())
# Out:
# headlines    0
# text         0
# dtype: int64

# %% [markdown]
# #### 정규화 및 불용어 제거

# %%
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

print("정규화 사전의 수: ", len(contractions))
# Out:
# 정규화 사전의 수:  120

# %%
print('불용어 개수 :', len(stopwords.words('english') ))
print(stopwords.words('english'))
# Out:
# 불용어 개수 : 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower()
    sentence = BeautifulSoup(sentence, "lxml").text
    sentence = re.sub(r'\([^)]*\)', '', sentence)
    sentence = re.sub('"','', sentence)
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")])
    sentence = re.sub(r"'s\b","", sentence)
    sentence = re.sub("[^a-zA-Z]", " ", sentence)
    sentence = re.sub('[m]{2,}', 'mm', sentence)
    
    # Text 불용어 제거
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
    # Headlines 불용어 미제거
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens

# %%
clean_text = []

# 전체 Text 데이터 전처리
for s in data['text']:
    clean_text.append(preprocess_sentence(s))

print("Text 전처리 후 결과: ", clean_text[:5])
# Out:
# Text 전처리 후 결과:  ['saurav kant alumnus upgrad iiit pg program machine learning artificial intelligence sr systems engineer infosys almost years work experience program upgrad degree career support helped transition data scientist tech mahindra salary hike upgrad online power learning powered lakh careers', 'kunal shah credit card bill payment platform cred gave users chance win free food swiggy one year pranav kaushik delhi techie bagged reward spending cred coins users get one cred coin per rupee bill paid used avail rewards brands like ixigo bookmyshow ubereats cult fit', 'new zealand defeated india wickets fourth odi hamilton thursday win first match five match odi series india lost international match rohit sharma captaincy consecutive victories dating back march match witnessed india getting seventh lowest total odi cricket history', 'aegon life iterm insurance plan customers enjoy tax benefits premiums paid save taxes plan provides life cover age years also customers options insure critical illnesses disability accidental death benefit rider life cover age years', 'speaking sexual harassment allegations rajkumar hirani sonam kapoor said known hirani many years true metoo movement get derailed metoo movement always believe woman case need reserve judgment added hirani accused assistant worked sanju']

# %%
clean_headline = []

# 전체 headlines 데이터 전처리
for s in data['headlines']:
    clean_headline.append(preprocess_sentence(s, False))

print("Headlines 전처리 후 결과: ", clean_headline[:5])
# Out:
# Headlines 전처리 후 결과:  ['upgrad learner switches to career in ml al with salary hike', 'delhi techie wins free food from swiggy for one year on cred', 'new zealand end rohit sharma led india match winning streak', 'aegon life iterm insurance plan helps customers save tax', 'have known hirani for yrs what if metoo claims are not true sonam']

# %%
data['headlines'] = clean_headline
data['text'] = clean_text

data.replace('', np.nan, inplace=True)

# %%
print(data.isnull().sum())
# Out:
# headlines    0
# text         0
# dtype: int64

# %% [markdown]
# ### 3) 데이터셋 분리

# %%
headline_len = [len(s.split()) for s in data['headlines']]
text_len = [len(s.split()) for s in data['text']]

print('헤드라인의 최소 길이 : {}'.format(np.min(headline_len)))
print('헤드라인의 최대 길이 : {}'.format(np.max(headline_len)))
print('헤드라인의 평균 길이 : {}'.format(np.mean(headline_len)))
print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))

plt.subplot(1,2,1)
plt.boxplot(headline_len)
plt.title('Headlines')

plt.subplot(1,2,2)
plt.boxplot(text_len)
plt.title('Text')
plt.tight_layout()

plt.show()
plt.title('Headlines')
plt.hist(headline_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Text')
plt.hist(text_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 헤드라인의 최소 길이 : 1
# 헤드라인의 최대 길이 : 16
# 헤드라인의 평균 길이 : 9.299532330215534
# 텍스트의 최소 길이 : 1
# 텍스트의 최대 길이 : 60
# 텍스트의 평균 길이 : 35.09968483123221

# %%
text_max_len = 50
headline_max_len = 15

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s.split()) <= max_len):
        cnt = cnt + 1
        
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))

# %%
below_threshold_len(headline_max_len,  data['headlines'])
below_threshold_len(text_max_len, data['text'])
# Out:
# 전체 샘플 중 길이가 15 이하인 샘플의 비율: 0.9999694997966653
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 0.9998576657177715

# %%
data = data[data['headlines'].apply(lambda x: len(x.split()) <= headline_max_len)]
data = data[data['text'].apply(lambda x: len(x.split()) <= text_max_len)]
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98343

# %% [markdown]
# #### 시작 및 종료 토큰 추가

# %%
data['decoder_input'] = data['headlines'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['headlines'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
#                                            headlines  \
# 0  upgrad learner switches to career in ml al wit...
# 1  delhi techie wins free food from swiggy for on...
# 2  new zealand end rohit sharma led india match w...
# 3  aegon life iterm insurance plan helps customer...
# 4  have known hirani for yrs what if metoo claims...
#
#                                                 text  \
# 0  saurav kant alumnus upgrad iiit pg program mac...
# 1  kunal shah credit card bill payment platform c...
# 2  new zealand defeated india wickets fourth odi ...
# 3  aegon life iterm insurance plan customers enjo...
# 4  speaking sexual harassment allegations rajkuma...
#
#                                        decoder_input  \
# 0  sostoken upgrad learner switches to career in ...
# 1  sostoken delhi techie wins free food from swig...
# 2  sostoken new zealand end rohit sharma led indi...
# 3  sostoken aegon life iterm insurance plan helps...
# 4  sostoken have known hirani for yrs what if met...
#
#                                       decoder_target
# 0  upgrad learner switches to career in ml al wit...
# 1  delhi techie wins free food from swiggy for on...
# 2  new zealand end rohit sharma led india match w...
# 3  aegon life iterm insurance plan helps customer...
# 4  have known hirani for yrs what if metoo claims...

# %%
encoder_input = np.array(data['text'])
decoder_input = np.array(data['decoder_input'])
decoder_target = np.array(data['decoder_target'])

# %%
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)
# Out:
# [66105 54148  5419 ... 26739 95916  9963]

# %%
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

# %%
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :',n_of_val)
# Out:
# 테스트 데이터의 수 : 19668

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 78675
# 훈련 레이블의 개수 : 78675
# 테스트 데이터의 개수 : 19668
# 테스트 레이블의 개수 : 19668

# %% [markdown]
# ### 4) 단어 집합 생성 및 정수 인코딩

# %%
src_tokenizer = Tokenizer()
src_tokenizer.fit_on_texts(encoder_input_train)

# %%
src_tokenizer.word_index
# Out:
# {'said': 1,
#  'india': 2,
#  'year': 3,
#  'added': 4,
#  'us': 5,
#  'also': 6,
#  'first': 7,
#  'government': 8,
#  'police': 9,
#  'people': 10,
#  'indian': 11,
#  'old': 12,
#  'two': 13,
#  'minister': 14,
#  'film': 15,
#  'president': 16,
#  'one': 17,
#  'world': 18,
#  'crore': 19,
#  'court': 20,
#  'state': 21,
#  'years': 22,
#  'would': 23,
#  'reportedly': 24,
#  'new': 25,
#  'delhi': 26,
#  'time': 27,
#  'former': 28,
#  'last': 29,
#  'three': 30,
#  'reports': 31,
#  'company': 32,
#  'earlier': 33,
#  'like': 34,
#  'congress': 35,
#  'based': 36,
#  'man': 37,
#  'bjp': 38,
#  'country': 39,
#  'day': 40,
#  'claimed': 41,
#  'team': 42,
#  'modi': 43,
#  'trump': 44,
#  'pakistan': 45,
#  'chief': 46,
#  'accused': 47,
#  'singh': 48,
#  'pm': 49,
#  'million': 50,
#  'actor': 51,
#  'women': 52,
#  'allegedly': 53,
#  'according': 54,
#  'made': 55,
#  'party': 56,
#  'wednesday': 57,
#  'friday': 58,
#  'pradesh': 59,
#  'monday': 60,
#  'tuesday': 61,
#  'comes': 62,
#  'lakh': 63,
#  'called': 64,
#  'woman': 65,
#  'video': 66,
#  'around': 67,
#  'asked': 68,
#  'thursday': 69,
#  'billion': 70,
#  'tweeted': 71,
#  'test': 72,
#  'khan': 73,
#  'mumbai': 74,
#  'including': 75,
#  'took': 76,
#  'case': 77,
#  'actress': 78,
#  'cm': 79,
#  'national': 80,
#  'revealed': 81,
#  'four': 82,
#  'could': 83,
#  'found': 84,
#  'saturday': 85,
#  'sunday': 86,
#  'officials': 87,
#  'arrested': 88,
#  'five': 89,
#  'leader': 90,
#  'match': 91,
#  'second': 92,
#  'wrote': 93,
#  'group': 94,
#  'following': 95,
#  'high': 96,
#  'announced': 97,
#  'used': 98,
#  'captain': 99,
#  'however': 100,
#  'since': 101,
#  'startup': 102,
#  'take': 103,
#  'users': 104,
#  'alleged': 105,
#  'notably': 106,
#  'china': 107,
#  'media': 108,
#  'narendra': 109,
#  'part': 110,
#  'family': 111,
#  'cricket': 112,
#  'killed': 113,
#  'bank': 114,
#  'due': 115,
#  'th': 116,
#  'may': 117,
#  'make': 118,
#  'ceo': 119,
#  'get': 120,
#  'international': 121,
#  'led': 122,
#  'adding': 123,
#  'days': 124,
#  'security': 125,
#  'donald': 126,
#  'set': 127,
#  'six': 128,
#  'per': 129,
#  'facebook': 130,
#  'gandhi': 131,
#  'month': 132,
#  'air': 133,
#  'twitter': 134,
#  'south': 135,
#  'house': 136,
#  'kapoor': 137,
#  'number': 138,
#  'home': 139,
#  'life': 140,
#  'data': 141,
#  'saying': 142,
#  'series': 143,
#  'work': 144,
#  'report': 145,
#  'picture': 146,
#  'incident': 147,
#  'help': 148,
#  'prime': 149,
#  'north': 150,
#  'official': 151,
#  'another': 152,
#  'later': 153,
#  'girl': 154,
#  'using': 155,
#  'wife': 156,
#  'social': 157,
#  'several': 158,
#  'seen': 159,
#  'car': 160,
#  'back': 161,
#  'show': 162,
#  'next': 163,
#  'uttar': 164,
#  'board': 165,
#  'kumar': 166,
#  'supreme': 167,
#  'post': 168,
#  'students': 169,
#  'least': 170,
#  'australia': 171,
#  'released': 172,
#  'talking': 173,
#  'public': 174,
#  'week': 175,
#  'google': 176,
#  'hospital': 177,
#  'elections': 178,
#  'money': 179,
#  'become': 180,
#  'union': 181,
#  'rahul': 182,
#  'third': 183,
#  'city': 184,
#  'filed': 185,
#  'launched': 186,
#  'among': 187,
#  'upcoming': 188,
#  'death': 189,
#  'months': 190,
#  'kohli': 191,
#  'recently': 192,
#  'taken': 193,
#  'cup': 194,
#  'nearly': 195,
#  'record': 196,
#  'without': 197,
#  'user': 198,
#  'men': 199,
#  'school': 200,
#  'even': 201,
#  'got': 202,
#  'children': 203,
#  'technology': 204,
#  'director': 205,
#  'shared': 206,
#  'centre': 207,
#  'run': 208,
#  'online': 209,
#  'uk': 210,
#  'many': 211,
#  'worth': 212,
#  'win': 213,
#  'son': 214,
#  'ever': 215,
#  'named': 216,
#  'times': 217,
#  'others': 218,
#  'away': 219,
#  'co': 220,
#  'release': 221,
#  'came': 222,
#  'attack': 223,
#  'hit': 224,
#  'researchers': 225,
#  'use': 226,
#  'law': 227,
#  'ministry': 228,
#  'held': 229,
#  'deal': 230,
#  'shah': 231,
#  'korea': 232,
#  'cannot': 233,
#  'long': 234,
#  'sharma': 235,
#  'place': 236,
#  'district': 237,
#  'father': 238,
#  'final': 239,
#  'told': 240,
#  'across': 241,
#  'making': 242,
#  'given': 243,
#  'reported': 244,
#  'open': 245,
#  'england': 246,
#  'body': 247,
#  'order': 248,
#  'founder': 249,
#  'system': 250,
#  'died': 251,
#  'capital': 252,
#  'event': 253,
#  'general': 254,
#  'directed': 255,
#  'members': 256,
#  'received': 257,
#  'water': 258,
#  'come': 259,
#  'army': 260,
#  'working': 261,
#  'app': 262,
#  'along': 263,
#  'every': 264,
#  'taking': 265,
#  'daughter': 266,
#  'american': 267,
#  'want': 268,
#  'person': 269,
#  'apple': 270,
#  'hours': 271,
#  'lost': 272,
#  'runs': 273,
#  'best': 274,
#  'tax': 275,
#  'assembly': 276,
#  'go': 277,
#  'department': 278,
#  'flight': 279,
#  'top': 280,
#  'way': 281,
#  'play': 282,
#  'started': 283,
#  'chinese': 284,
#  'pay': 285,
#  'karnataka': 286,
#  'decision': 287,
#  'firm': 288,
#  'raised': 289,
#  'largest': 290,
#  'mother': 291,
#  'fire': 292,
#  'left': 293,
#  'space': 294,
#  'never': 295,
#  'university': 296,
#  'seven': 297,
#  'went': 298,
#  'became': 299,
#  'human': 300,
#  'highest': 301,
#  'injured': 302,
#  'cricketer': 303,
#  'kashmir': 304,
#  'today': 305,
#  'united': 306,
#  'right': 307,
#  'within': 308,
#  'services': 309,
#  'name': 310,
#  'australian': 311,
#  'odi': 312,
#  'airport': 313,
#  'end': 314,
#  'authorities': 315,
#  'officer': 316,
#  'employees': 317,
#  'service': 318,
#  'chairman': 319,
#  'player': 320,
#  'countries': 321,
#  'speaking': 322,
#  'star': 323,
#  'good': 324,
#  'well': 325,
#  'states': 326,
#  'playing': 327,
#  'bengaluru': 328,
#  'kerala': 329,
#  'issued': 330,
#  'ram': 331,
#  'read': 332,
#  'food': 333,
#  'films': 334,
#  'action': 335,
#  'league': 336,
#  'information': 337,
#  'total': 338,
#  'power': 339,
#  'gold': 340,
#  'known': 341,
#  'meeting': 342,
#  'maharashtra': 343,
#  'companies': 344,
#  'russia': 345,
#  'december': 346,
#  'support': 347,
#  'meanwhile': 348,
#  'round': 349,
#  'posted': 350,
#  'sexual': 351,
#  'march': 352,
#  'sent': 353,
#  'free': 354,
#  'move': 355,
#  'gujarat': 356,
#  'give': 357,
#  'central': 358,
#  'russian': 359,
#  'private': 360,
#  'eight': 361,
#  'role': 362,
#  'currently': 363,
#  'business': 364,
#  'foreign': 365,
#  'cases': 366,
#  'office': 367,
#  'head': 368,
#  'share': 369,
#  'virat': 370,
#  'june': 371,
#  'near': 372,
#  'face': 373,
#  'slammed': 374,
#  'election': 375,
#  'going': 376,
#  'tweet': 377,
#  'ahead': 378,
#  'list': 379,
#  'special': 380,
#  'instagram': 381,
#  'love': 382,
#  'child': 383,
#  'un': 384,
#  'visit': 385,
#  'issue': 386,
#  'scored': 387,
#  'commission': 388,
#  'claiming': 389,
#  'amid': 390,
#  'ball': 391,
#  'ban': 392,
#  'war': 393,
#  'song': 394,
#  'think': 395,
#  'investigation': 396,
#  'much': 397,
#  'market': 398,
#  'scheduled': 399,
#  'salman': 400,
#  'statement': 401,
#  'tamil': 402,
#  'ago': 403,
#  'registered': 404,
#  'ex': 405,
#  'need': 406,
#  'know': 407,
#  'april': 408,
#  'january': 409,
#  'sabha': 410,
#  'husband': 411,
#  'boy': 412,
#  'senior': 413,
#  'anti': 414,
#  'ipl': 415,
#  'august': 416,
#  'bihar': 417,
#  'september': 418,
#  'health': 419,
#  'nuclear': 420,
#  'uber': 421,
#  'played': 422,
#  'passengers': 423,
#  'military': 424,
#  'non': 425,
#  'secretary': 426,
#  'passed': 427,
#  'singer': 428,
#  'real': 429,
#  'punjab': 430,
#  'west': 431,
#  'defence': 432,
#  'funding': 433,
#  'global': 434,
#  'shows': 435,
#  'class': 436,
#  'yadav': 437,
#  'news': 438,
#  'see': 439,
#  'shot': 440,
#  'feature': 441,
#  'platform': 442,
#  'leaders': 443,
#  'development': 444,
#  'sri': 445,
#  'age': 446,
#  'rape': 447,
#  'ordered': 448,
#  'train': 449,
#  'put': 450,
#  'pakistani': 451,
#  'finance': 452,
#  'student': 453,
#  'inside': 454,
#  'mp': 455,
#  'complaint': 456,
#  'cbi': 457,
#  'players': 458,
#  'recent': 459,
#  'late': 460,
#  'political': 461,
#  'launch': 462,
#  'denied': 463,
#  'allegations': 464,
#  'area': 465,
#  'failed': 466,
#  'major': 467,
#  'member': 468,
#  'station': 469,
#  'trying': 470,
#  'wedding': 471,
#  'dead': 472,
#  'bill': 473,
#  'wanted': 474,
#  'act': 475,
#  'financial': 476,
#  'giant': 477,
#  'female': 478,
#  'towards': 479,
#  'fake': 480,
#  'force': 481,
#  'medical': 482,
#  'different': 483,
#  'expected': 484,
#  'bollywood': 485,
#  'couple': 486,
#  'side': 487,
#  'project': 488,
#  'suicide': 489,
#  'claims': 490,
#  'july': 491,
#  'lead': 492,
#  'game': 493,
#  'still': 494,
#  'dhoni': 495,
#  'october': 496,
#  'allowed': 497,
#  'award': 498,
#  'road': 499,
#  'jail': 500,
#  'november': 501,
#  'getting': 502,
#  'british': 503,
#  'batsman': 504,
#  'agency': 505,
#  'founded': 506,
#  'paid': 507,
#  'past': 508,
#  'stop': 509,
#  'minutes': 510,
#  'sachin': 511,
#  'outside': 512,
#  'games': 513,
#  'change': 514,
#  'despite': 515,
#  'history': 516,
#  'earth': 517,
#  'white': 518,
#  'stated': 519,
#  'local': 520,
#  'forces': 521,
#  'workers': 522,
#  'building': 523,
#  'birthday': 524,
#  'amazon': 525,
#  'decided': 526,
#  'control': 527,
#  'victim': 528,
#  'married': 529,
#  'mark': 530,
#  'calling': 531,
#  'rajasthan': 532,
#  'study': 533,
#  'rights': 534,
#  'priyanka': 535,
#  'korean': 536,
#  'phone': 537,
#  'nadu': 538,
#  'campaign': 539,
#  'saudi': 540,
#  'committee': 541,
#  'scientists': 542,
#  'driver': 543,
#  'plans': 544,
#  'together': 545,
#  'reacting': 546,
#  'nation': 547,
#  'jammu': 548,
#  'quarter': 549,
#  'look': 550,
#  'railway': 551,
#  'vice': 552,
#  'musk': 553,
#  'temple': 554,
#  'madhya': 555,
#  'winning': 556,
#  'refused': 557,
#  'violence': 558,
#  'account': 559,
#  'great': 560,
#  'iran': 561,
#  'parents': 562,
#  'debut': 563,
#  'till': 564,
#  'ali': 565,
#  'football': 566,
#  'big': 567,
#  'sharing': 568,
#  'letter': 569,
#  'cost': 570,
#  'coach': 571,
#  'gst': 572,
#  'fell': 573,
#  'nine': 574,
#  'pictures': 575,
#  'planning': 576,
#  'behind': 577,
#  'always': 578,
#  'seeking': 579,
#  'half': 580,
#  'black': 581,
#  'africa': 582,
#  'starrer': 583,
#  'london': 584,
#  'live': 585,
#  'matches': 586,
#  'instead': 587,
#  'mobile': 588,
#  'night': 589,
#  'gave': 590,
#  'justice': 591,
#  'provide': 592,
#  'leave': 593,
#  'banned': 594,
#  'filmmaker': 595,
#  'border': 596,
#  'cash': 597,
#  'tesla': 598,
#  'single': 599,
#  'matter': 600,
#  'met': 601,
#  'haryana': 602,
#  'light': 603,
#  'developed': 604,
#  'season': 605,
#  'personal': 606,
#  'nasa': 607,
#  'self': 608,
#  'parliament': 609,
#  'muslim': 610,
#  'fund': 611,
#  'fourth': 612,
#  'previous': 613,
#  'declared': 614,
#  'land': 615,
#  'biggest': 616,
#  'call': 617,
#  'bachchan': 618,
#  'affairs': 619,
#  'protest': 620,
#  'aadhaar': 621,
#  'career': 622,
#  'murder': 623,
#  'amount': 624,
#  'must': 625,
#  'french': 626,
#  'probe': 627,
#  'club': 628,
#  'offered': 629,
#  'better': 630,
#  'charges': 631,
#  'confirmed': 632,
#  'sale': 633,
#  'turned': 634,
#  'investors': 635,
#  'brother': 636,
#  'tournament': 637,
#  'loss': 638,
#  'intelligence': 639,
#  'lok': 640,
#  'start': 641,
#  'showed': 642,
#  'yet': 643,
#  'innings': 644,
#  'industry': 645,
#  'km': 646,
#  'harassment': 647,
#  'aircraft': 648,
#  'bengal': 649,
#  'stating': 650,
#  'admitted': 651,
#  'already': 652,
#  'opposition': 653,
#  'far': 654,
#  'level': 655,
#  'education': 656,
#  'model': 657,
#  'written': 658,
#  'current': 659,
#  'staff': 660,
#  'indians': 661,
#  'tried': 662,
#  'price': 663,
#  'suspended': 664,
#  'girls': 665,
#  'happy': 666,
#  'created': 667,
#  'say': 668,
#  'return': 669,
#  'banks': 670,
#  'rukh': 671,
#  'cut': 672,
#  'shares': 673,
#  'let': 674,
#  'able': 675,
#  'driving': 676,
#  'baby': 677,
#  'japan': 678,
#  'village': 679,
#  'income': 680,
#  'chopra': 681,
#  'photo': 682,
#  'caused': 683,
#  'issues': 684,
#  'owned': 685,
#  'hotel': 686,
#  'done': 687,
#  'spokesperson': 688,
#  'vehicles': 689,
#  'hyderabad': 690,
#  'champions': 691,
#  'nations': 692,
#  'period': 693,
#  'oil': 694,
#  'include': 695,
#  'vehicle': 696,
#  'farmers': 697,
#  'increase': 698,
#  'officers': 699,
#  'appointed': 700,
#  'flipkart': 701,
#  'investment': 702,
#  'tv': 703,
#  'create': 704,
#  'reach': 705,
#  'allow': 706,
#  'fight': 707,
#  'rbi': 708,
#  'missing': 709,
#  'gone': 710,
#  'wickets': 711,
#  'wearing': 712,
#  'job': 713,
#  'meet': 714,
#  'defeated': 715,
#  'keep': 716,
#  'organisation': 717,
#  'trade': 718,
#  'stake': 719,
#  'economic': 720,
#  'character': 721,
#  'carrying': 722,
#  'hand': 723,
#  'suggested': 724,
#  'governor': 725,
#  'demanded': 726,
#  'form': 727,
#  'accounts': 728,
#  'full': 729,
#  'sold': 730,
#  'february': 731,
#  'treatment': 732,
#  'council': 733,
#  'less': 734,
#  'sanjay': 735,
#  'plan': 736,
#  'response': 737,
#  'forced': 738,
#  'hindu': 739,
#  'personnel': 740,
#  'term': 741,
#  'things': 742,
#  'showing': 743,
#  'afghanistan': 744,
#  'process': 745,
#  'customers': 746,
#  'broke': 747,
#  'mla': 748,
#  'find': 749,
#  'ongoing': 750,
#  'bus': 751,
#  'related': 752,
#  'proposed': 753,
#  'score': 754,
#  'marriage': 755,
#  'reached': 756,
#  'sex': 757,
#  'cars': 758,
#  'hearing': 759,
#  'policy': 760,
#  'passenger': 761,
#  'involved': 762,
#  'reliance': 763,
#  'features': 764,
#  'karan': 765,
#  'zealand': 766,
#  'talks': 767,
#  'operations': 768,
#  'lanka': 769,
#  'asking': 770,
#  'title': 771,
#  'airline': 772,
#  'warned': 773,
#  'region': 774,
#  'story': 775,
#  'commerce': 776,
#  'sought': 777,
#  'doctors': 778,
#  'various': 779,
#  'spot': 780,
#  'date': 781,
#  'illegal': 782,
#  'adityanath': 783,
#  'caught': 784,
#  'deepika': 785,
#  'attacks': 786,
#  'lot': 787,
#  'compared': 788,
#  'travel': 789,
#  'bcci': 790,
#  'legal': 791,
#  'line': 792,
#  'safety': 793,
#  'born': 794,
#  'research': 795,
#  'signed': 796,
#  'rao': 797,
#  'committed': 798,
#  'forward': 799,
#  'giving': 800,
#  'products': 801,
#  'electric': 802,
#  'addressing': 803,
#  'feel': 804,
#  'continue': 805,
#  'access': 806,
#  'room': 807,
#  'community': 808,
#  'andhra': 809,
#  'almost': 810,
#  'discovered': 811,
#  'terror': 812,
#  'future': 813,
#  'ensure': 814,
#  'corporation': 815,
#  'revenue': 816,
#  'seats': 817,
#  'friends': 818,
#  'fans': 819,
#  'vijay': 820,
#  'viral': 821,
#  'corruption': 822,
#  'ranveer': 823,
#  'threatened': 824,
#  'notice': 825,
#  'jaitley': 826,
#  'saw': 827,
#  'friend': 828,
#  'whose': 829,
#  'anil': 830,
#  'red': 831,
#  'offer': 832,
#  'looking': 833,
#  'yogi': 834,
#  'tendulkar': 835,
#  'strike': 836,
#  'television': 837,
#  'ended': 838,
#  'built': 839,
#  'deputy': 840,
#  'schools': 841,
#  'bangladesh': 842,
#  'increased': 843,
#  'pacer': 844,
#  'kejriwal': 845,
#  'removed': 846,
#  'whatsapp': 847,
#  'someone': 848,
#  'rohit': 849,
#  'killing': 850,
#  'points': 851,
#  'management': 852,
#  'aged': 853,
#  'conducted': 854,
#  'hour': 855,
#  'york': 856,
#  'net': 857,
#  'internet': 858,
#  'close': 859,
#  'kapil': 860,
#  'citizens': 861,
#  'kg': 862,
#  'arrest': 863,
#  'stars': 864,
#  'suffered': 865,
#  'traffic': 866,
#  'festival': 867,
#  'delivery': 868,
#  'hai': 869,
#  'website': 870,
#  'german': 871,
#  'asian': 872,
#  'airlines': 873,
#  'medal': 874,
#  'value': 875,
#  'really': 876,
#  'weeks': 877,
#  'administration': 878,
#  'english': 879,
#  'shooting': 880,
#  'victory': 881,
#  'birth': 882,
#  'soon': 883,
#  'dismissed': 884,
#  'judge': 885,
#  'available': 886,
#  'protests': 887,
#  'imposed': 888,
#  'digital': 889,
#  'opened': 890,
#  'college': 891,
#  'al': 892,
#  'claim': 893,
#  'emergency': 894,
#  'agreed': 895,
#  'helped': 896,
#  'akshay': 897,
#  'music': 898,
#  'actors': 899,
#  'leading': 900,
#  'aimed': 901,
#  'small': 902,
#  'similar': 903,
#  'worked': 904,
#  'began': 905,
#  'association': 906,
#  'rejected': 907,
#  'prasad': 908,
#  'affected': 909,
#  'whether': 910,
#  'germany': 911,
#  'growth': 912,
#  'sena': 913,
#  'book': 914,
#  'areas': 915,
#  'jobs': 916,
#  'fine': 917,
#  'front': 918,
#  'low': 919,
#  'chennai': 920,
#  'owner': 921,
#  'brand': 922,
#  'cover': 923,
#  'ceremony': 924,
#  'wants': 925,
#  'rules': 926,
#  'early': 927,
#  'victims': 928,
#  'annual': 929,
#  'ms': 930,
#  'tests': 931,
#  'injuries': 932,
#  'approved': 933,
#  'buy': 934,
#  'interview': 935,
#  'elon': 936,
#  'mission': 937,
#  'details': 938,
#  'production': 939,
#  'rate': 940,
#  'trophy': 941,
#  'spinner': 942,
#  'followed': 943,
#  'parties': 944,
#  'fifa': 945,
#  'france': 946,
#  'fashion': 947,
#  'ambani': 948,
#  'included': 949,
#  'wrong': 950,
#  'device': 951,
#  'aap': 952,
#  'image': 953,
#  'search': 954,
#  'kim': 955,
#  'missile': 956,
#  'surfaced': 957,
#  'metro': 958,
#  'interest': 959,
#  'charge': 960,
#  'urged': 961,
#  'grand': 962,
#  'kolkata': 963,
#  'lives': 964,
#  'joined': 965,
#  'site': 966,
#  'fraud': 967,
#  'amit': 968,
#  'kangana': 969,
#  'funds': 970,
#  'plane': 971,
#  'programme': 972,
#  'goal': 973,
#  'youth': 974,
#  'charged': 975,
#  'sanctions': 976,
#  'iphone': 977,
#  'training': 978,
#  'scheme': 979,
#  'anyone': 980,
#  'brought': 981,
#  'asia': 982,
#  'executive': 983,
#  'accident': 984,
#  'something': 985,
#  'militants': 986,
#  'de': 987,
#  'employee': 988,
#  'fast': 989,
#  'ground': 990,
#  'opening': 991,
#  'journalist': 992,
#  'feet': 993,
#  'position': 994,
#  'fan': 995,
#  'tennis': 996,
#  'bring': 997,
#  'islamic': 998,
#  'european': 999,
#  'relationship': 1000,
#  ...}

# %%
threshold = 9
total_cnt = len(src_tokenizer.word_index)
rare_cnt = 0
total_freq = 0
rare_freq = 0

for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 69641
# 등장 빈도가 8번 이하인 희귀 단어의 수: 50240
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 19401
# 단어 집합에서 희귀 단어의 비율: 72.14141095044586
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 4.234010339961449

# %%
src_vocab = 19000
src_tokenizer = Tokenizer(num_words=src_vocab)
src_tokenizer.fit_on_texts(encoder_input_train)

# %%
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train) 
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

print(encoder_input_train[:3])
# Out:
# [[8, 2068, 2417, 14802, 46, 983, 316, 1085, 2263, 1196, 873, 1025, 1086, 772, 7337, 10960, 2131, 1196, 132, 103, 413, 994, 1196, 873, 127, 103, 960, 25, 994, 163, 175, 772, 151, 1], [67, 63, 10, 244, 3981, 26, 2, 3773, 2100, 25, 3, 60, 900, 2604, 866, 9143, 515, 7461, 9, 740, 315, 1781, 27, 1865, 2604, 2213, 3089, 866, 9, 6, 330, 17506, 770, 10, 103, 8820, 5492], [11, 995, 662, 5277, 405, 171, 844, 5336, 2338, 531, 9460, 6700, 134, 2618, 1159, 710, 6700, 415, 1239, 100, 1633, 844, 404, 310, 1239, 1921, 995, 161, 1922, 6866, 1013, 10711, 1633, 112, 33, 3]]

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)

# %%
threshold = 9
total_cnt = len(tar_tokenizer.word_index)
rare_cnt = 0
total_freq = 0
rare_freq = 0

for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 30062
# 등장 빈도가 8번 이하인 희귀 단어의 수: 21864
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 8198
# 단어 집합에서 희귀 단어의 비율: 72.72969196992881
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 6.533042789419002

# %%
tar_vocab = 9000
tar_tokenizer = Tokenizer(num_words=tar_vocab) 
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train) 
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

print('input')
print('input ',decoder_input_train[:5])
print('target')
print('decoder ',decoder_target_train[:5])
# Out:
# input
# input  [[1, 23, 1501, 3578, 6, 16, 6160, 69], [1, 4269, 853, 8200, 16, 12, 9, 4519, 7, 38, 40], [1, 29, 459, 1263, 3, 1722, 2842, 15, 203, 72, 891, 221], [1, 454, 966, 3, 159, 5, 7230, 865, 806], [1, 1155, 4143, 2481, 411, 4, 285, 207, 3480, 1223]]
# target
# decoder  [[23, 1501, 3578, 6, 16, 6160, 69, 2], [4269, 853, 8200, 16, 12, 9, 4519, 7, 38, 40, 2], [29, 459, 1263, 3, 1722, 2842, 15, 203, 72, 891, 221, 2], [454, 966, 3, 159, 5, 7230, 865, 806, 2], [1155, 4143, 2481, 411, 4, 285, 207, 3480, 1223, 2]]

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))

encoder_input_train = [sentence for index, sentence in enumerate(encoder_input_train) if index not in drop_train]
decoder_input_train = [sentence for index, sentence in enumerate(decoder_input_train) if index not in drop_train]
decoder_target_train = [sentence for index, sentence in enumerate(decoder_target_train) if index not in drop_train]

encoder_input_test = [sentence for index, sentence in enumerate(encoder_input_test) if index not in drop_test]
decoder_input_test = [sentence for index, sentence in enumerate(decoder_input_test) if index not in drop_test]
decoder_target_test = [sentence for index, sentence in enumerate(decoder_target_test) if index not in drop_test]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 0
# 삭제할 테스트 데이터의 개수 : 0
# 훈련 데이터의 개수 : 78675
# 훈련 레이블의 개수 : 78675
# 테스트 데이터의 개수 : 19668
# 테스트 레이블의 개수 : 19668

# %% [markdown]
# #### 패딩

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen=text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen=headline_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=headline_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen=headline_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=headline_max_len, padding='post')

# %% [markdown]
# ### 5) 모델 생성

# %%
embedding_dim = 128
hidden_size = 256

encoder_inputs = Input(shape=(text_max_len,))

enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout = 0.4, recurrent_dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
decoder_inputs = Input(shape=(None,))

dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs) 

model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 50, 128)      2432000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 50, 256), (N 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 256), (N 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    1152000     input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 256), (N 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 9000)   2313000     lstm_3[0][0]
# ==================================================================================================
# Total params: 7,736,104
# Trainable params: 7,736,104
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
attn_layer = AdditiveAttention(name='attention_layer')

attn_out = attn_layer([decoder_outputs, encoder_outputs])

decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 50, 128)      2432000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 50, 256), (N 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 256), (N 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    1152000     input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 256), (N 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AdditiveAttent (None, None, 256)    256         lstm_3[0][0]
#                                                                  lstm_2[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 512)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 9000)   4617000     concat_layer[0][0]
# ==================================================================================================
# Total params: 10,040,360
# Trainable params: 10,040,360
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, \
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test), \
          batch_size=512, callbacks=[es], epochs=50)
# Out:
# Epoch 1/50
# 154/154 [==============================] - 124s 753ms/step - loss: 4.6868 - val_loss: 4.3211
# Epoch 2/50
# 154/154 [==============================] - 116s 754ms/step - loss: 4.2122 - val_loss: 4.0220
# Epoch 3/50
# 154/154 [==============================] - 115s 750ms/step - loss: 3.9564 - val_loss: 3.7991
# Epoch 4/50
# 154/154 [==============================] - 115s 749ms/step - loss: 3.7286 - val_loss: 3.6247
# Epoch 5/50
# 154/154 [==============================] - 116s 751ms/step - loss: 3.5526 - val_loss: 3.5182
# Epoch 6/50
# 154/154 [==============================] - 116s 752ms/step - loss: 3.4074 - val_loss: 3.3955
# Epoch 7/50
# 154/154 [==============================] - 115s 747ms/step - loss: 3.2818 - val_loss: 3.3100
# Epoch 8/50
# 154/154 [==============================] - 115s 749ms/step - loss: 3.1689 - val_loss: 3.2432
# Epoch 9/50
# 154/154 [==============================] - 116s 753ms/step - loss: 3.0713 - val_loss: 3.1810
# Epoch 10/50
# 154/154 [==============================] - 116s 751ms/step - loss: 2.9829 - val_loss: 3.1294
# Epoch 11/50
# 154/154 [==============================] - 116s 752ms/step - loss: 2.9022 - val_loss: 3.0867
# Epoch 12/50
# 154/154 [==============================] - 115s 748ms/step - loss: 2.8295 - val_loss: 3.0478
# Epoch 13/50
# 154/154 [==============================] - 116s 756ms/step - loss: 2.7631 - val_loss: 3.0284
# Epoch 14/50
# 154/154 [==============================] - 116s 754ms/step - loss: 2.7009 - val_loss: 2.9926
# Epoch 15/50
# 154/154 [==============================] - 117s 757ms/step - loss: 2.6438 - val_loss: 2.9704
# Epoch 16/50
# 154/154 [==============================] - 116s 755ms/step - loss: 2.5903 - val_loss: 2.9544
# Epoch 17/50
# 154/154 [==============================] - 115s 749ms/step - loss: 2.5402 - val_loss: 2.9338
# Epoch 18/50
# 154/154 [==============================] - 115s 748ms/step - loss: 2.4922 - val_loss: 2.9165
# Epoch 19/50
# 154/154 [==============================] - 114s 743ms/step - loss: 2.4485 - val_loss: 2.9069
# Epoch 20/50
# 154/154 [==============================] - 114s 739ms/step - loss: 2.4052 - val_loss: 2.9004
# Epoch 21/50
# 154/154 [==============================] - 114s 743ms/step - loss: 2.3669 - val_loss: 2.8886
# Epoch 22/50
# 154/154 [==============================] - 114s 741ms/step - loss: 2.3288 - val_loss: 2.8890
# Epoch 23/50
# 154/154 [==============================] - 114s 743ms/step - loss: 2.2929 - val_loss: 2.8766
# Epoch 24/50
# 154/154 [==============================] - 114s 739ms/step - loss: 2.2596 - val_loss: 2.8686
# Epoch 25/50
# 154/154 [==============================] - 114s 741ms/step - loss: 2.2269 - val_loss: 2.8703
# Epoch 26/50
# 154/154 [==============================] - 114s 738ms/step - loss: 2.1960 - val_loss: 2.8630
# Epoch 27/50
# 154/154 [==============================] - 114s 741ms/step - loss: 2.1676 - val_loss: 2.8642
# Epoch 28/50
# 154/154 [==============================] - 114s 740ms/step - loss: 2.1384 - val_loss: 2.8599
# Epoch 29/50
# 154/154 [==============================] - 114s 741ms/step - loss: 2.1110 - val_loss: 2.8593
# Epoch 30/50
# 154/154 [==============================] - 114s 740ms/step - loss: 2.0845 - val_loss: 2.8604
# Epoch 31/50
# 154/154 [==============================] - 114s 742ms/step - loss: 2.0606 - val_loss: 2.8617
# Epoch 00031: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# ### 6) 모델 테스트

# %%
src_index_to_word = src_tokenizer.index_word
tar_word_to_index = tar_tokenizer.word_index
tar_index_to_word = tar_tokenizer.index_word

# %%
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)

decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf = attn_layer([decoder_outputs2, decoder_hidden_state_input])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if (sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (headline_max_len-1)):
            stop_condition = True

        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        e_h, e_c = h, c

    return decoded_sentence

# %% [markdown]
# #### 텍스트 요약

# %%
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if (i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if ((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

# %%
for i in range(50, 60):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : hyderabad police suspecting case human sacrifice super blue blood moon month old infant severed head found terrace residence hyderabad body infant found yet police failed confirm baby gender head found day lunar eclipse
# 실제 요약 : human sacrifice suspected after infant head found in hyd
# 예측 요약 :  police saves baby in chest after killing
#
#
# 원문 : lending crowdfunding model used raise loans using online platform matches lenders borrowers provide unsecured loans government said peer peer lending platforms would treated non banking financial companies regulated rbi lending firms hold lenders money giving borrowers usually individuals small businesses
# 실제 요약 : what is lending that the rbi plans to regulate
# 예측 요약 :  airtel to pay crore to airtel for tax evasion
#
#
# 원문 : decomposed body class female student found hanging ceiling fan hostel room mysuru sunday girl feeling guilty spent night boyfriend returning school trip reports said warden hostel suspended boy booked
# 실제 요약 : class girl kills self after spending night with boyfriend
# 예측 요약 :  student found hanging from school hostel in delhi
#
#
# 원문 : afghanistan wicketkeeper batsman mohammad shahzad named man match run knock india tuesday said match ending tie fair happy hours ground without result shahzad added talking hundred said feeling proud played like best asian side
# 실제 요약 : hours on ground no result is not fair shahzad on tie vs india
# 예측 요약 :  pak batsman to be made in cricket cricket match
#
#
# 원문 : kerala government tuesday issued order reducing minimum distance maintained bars educational institutions places worship metres previous metre limit decision applicable four star five star heritage hotels three star hotels beer wine maintain existing metre distance
# 실제 요약 : kerala govt allows bars within metres of schools temples
# 예측 요약 :  kerala govt to ban on sale of kerala
#
#
# 원문 : french intelligence agent tasked monitoring paris cleric suspected extremist interpretation islam mistakenly texted agent intended update one colleagues progress investigation suspect reportedly responded text also warned associates might government surveillance
# 실제 요약 : french agent accidentally texts he was spying on
# 예측 요약 :  russian spy agency faces over gay gay gay flag
#
#
# 원문 : india first prime minister jawaharlal nehru predicted atal bihari vajpayee would become prime minister country one day introducing foreign nehru said young man one day become country prime minister vajpayee served pm first time
# 실제 요약 : nehru predicted atal bihari vajpayee would become pm one day
# 예측 요약 :  late pm vajpayee was an indian pm vajpayee
#
#
# 원문 : facebook monday announced block advertisements pages repeatedly share fake news facebook claimed move help reduce distribution false news keep pages spread making money however facebook added pages may eligible start running ads stop sharing false news
# 실제 요약 : facebook to block ads from pages that share fake news
# 예측 요약 :  facebook suspends news accounts for fake news
#
#
# 원문 : nasa juno spacecraft revealed giant cyclone jupiter north pole eight smaller cyclones another image depicted cyclone south pole surrounded five cyclones km suggesting polar magnetic fields central storm may contain core high pressure high temperature rocks perhaps water said project scientist
# 실제 요약 : nasa probe shows multiple storms over jupiter north pole
# 예측 요약 :  nasa probe to send solar panels to mars
#
#
# 원문 : australian police found one metre long crocodile walking streets victoria melbourne christmas day crocodile reportedly attempted run bushes caught tail care state wildlife authorities pet owners victoria allowed keep crocodiles metre length
# 실제 요약 : crocodile found walking on street in australia on christmas
# 예측 요약 :  year old tree finds tree inside crocodile in

# %% [markdown]
# ### 7) Summa 사용해보기

# %%
import requests
from summa.summarizer import summarize

# %%
summa_data = pd.read_csv('news_summary_more.csv', encoding='iso-8859-1')
print(summa_data[:1500])
# Out:
#                                               headlines  \
# 0     upGrad learner switches to career in ML & Al w...
# 1     Delhi techie wins free food from Swiggy for on...
# 2     New Zealand end Rohit Sharma-led India's 12-ma...
# 3     Aegon life iTerm insurance plan helps customer...
# 4     Have known Hirani for yrs, what if MeToo claim...
# ...                                                 ...
# 1495  Have seen Sachin Tendulkar get angry but not M...
# 1496  Player ensures wife stays dry in rain during A...
# 1497  Federer denied entry into locker room by secur...
# 1498  42/42 seats in West Bengal: CM Mamata's cutout...
# 1499  Court refuses chargesheet by Delhi Police agai...
#
#                                                    text
# 0     Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1     Kunal Shah's credit card bill payment platform...
# 2     New Zealand defeated India by 8 wickets in the...
# 3     With Aegon Life iTerm Insurance plan, customer...
# 4     Speaking about the sexual harassment allegatio...
# ...                                                 ...
# 1495  India head coach Ravi Shastri has said that he...
# 1496  Italian tennis player Andreas Seppi ensured hi...
# 1497  World number three Roger Federer was stopped b...
# 1498  A cutout of TMC chief and West Bengal CM Mamat...
# 1499  A Delhi court on Saturday pulled up Delhi Poli...
#
# [1500 rows x 2 columns]

# %%
for i in range(50, 60):
    print("headlines : ", summarize(summa_data['text'][i], ratio=0.5))
# Out:
# headlines :  Former Finance Minister Yashwant Sinha on Tuesday demanded a probe into the alleged diversion of loans worth Ã¢ÂÂ¹31,000 crore by Dewan Housing Finance (DHFL).
# headlines :  Boeing retained its position as the world's largest planemaker for the seventh straight year, delivering 806 aircraft in 2018.
# headlines :
# headlines :  Further, its OnePlus 6 emerged as the highest selling premium smartphone of 2018 followed by OnePlus 6T.
# headlines :  Filmmaker Pooja Bhatt, while talking about the presentation of women in her films, said, "I can never look at a female body, even if it's naked, in a vulgar manner." "Our audience can say...the women in my films are bold or sensual, but never ever vulgar," she added.
# headlines :  Actress Mishti, who has featured in 'Manikarnika: The Queen of Jhansi', has said the film's co-director Kangana Ranaut made false promises to the cast.
# headlines :  The high-powered committee led by PM Narendra Modi to select the next CBI Director will meet again on February 1, Congress leader Mallikarjun Kharge has said.
# headlines :  Nevada State Athletic Commission has banned MMA fighters Conor McGregor and Khabib Nurmagomedov for six months and nine months respectively over their roles in the mass brawl that occurred after their fight at UFC 229 last October.
# headlines :  Pakistan captain Sarfaraz Ahmed, who has been banned for four matches over racist remarks, took an apparent dig at his critics by sharing a video of a child reciting 'log hai na' poem on Twitter.
# headlines :  Sreesanth further said the bookie tried dragging him into spot-fixing but he didn't fall for it.

# %%
for i in range(50, 60):
    print("원문 :", summa_data["text"][i])
    print("실제 요약 :", summa_data["headlines"][i])
    print("Extractive 요약 :", summarize(summa_data["text"][i], ratio=0.5))
    print("\n")
# Out:
# 원문 : Former Finance Minister Yashwant Sinha on Tuesday demanded a probe into the alleged diversion of loans worth Ã¢ÂÂ¹31,000 crore by Dewan Housing Finance (DHFL). All agencies including regulators of the government have failed to track nefarious deals, he said. This comes after a media report on Tuesday accused DHFL's controlling shareholders of diverting funds to shell companies to buy assets.
# 실제 요약 : Yashwant Sinha demands probe into alleged fund diversion by DHFL
# Extractive 요약 : Former Finance Minister Yashwant Sinha on Tuesday demanded a probe into the alleged diversion of loans worth Ã¢ÂÂ¹31,000 crore by Dewan Housing Finance (DHFL).
#
#
# 원문 : US-based Boeing on Wednesday reported annual sales worth $101.12 billion in 2018, the first time the planemaker's sales crossed the $100-billion mark in its 102-year history. The company said it expects to deliver between 895 and 905 commercial aircraft in 2019. Boeing retained its position as the world's largest planemaker for the seventh straight year, delivering 806 aircraft in 2018.
# 실제 요약 : Boeing sales cross $100bn for 1st time in its 102-yr history
# Extractive 요약 : Boeing retained its position as the world's largest planemaker for the seventh straight year, delivering 806 aircraft in 2018.
#
#
# 원문 : text
# 실제 요약 : headlines
# Extractive 요약 :
#
#
# 원문 : OnePlus has emerged as India's best-selling premium smartphone brand of 2018, as per a report by Counterpoint. It captured 36% of the market share in the premium segment, in Q4 2018. Further, its OnePlus 6 emerged as the highest selling premium smartphone of 2018 followed by OnePlus 6T.
# 실제 요약 : OnePlus named bestselling premium smartphone brand of 2018: Report
# Extractive 요약 : Further, its OnePlus 6 emerged as the highest selling premium smartphone of 2018 followed by OnePlus 6T.
#
#
# 원문 : Filmmaker Pooja Bhatt, while talking about the presentation of women in her films, said, "I can never look at a female body, even if it's naked, in a vulgar manner." "Our audience can say...the women in my films are bold or sensual, but never ever vulgar," she added. Pooja further said her censor board is her "own heart and mind".
# 실제 요약 : Can never look at female body, even if naked, in vulgar way: Pooja
# Extractive 요약 : Filmmaker Pooja Bhatt, while talking about the presentation of women in her films, said, "I can never look at a female body, even if it's naked, in a vulgar manner." "Our audience can say...the women in my films are bold or sensual, but never ever vulgar," she added.
#
#
# 원문 : Actress Mishti, who has featured in 'Manikarnika: The Queen of Jhansi', has said the film's co-director Kangana Ranaut made false promises to the cast. "Kangana had said, 'I want dates because all characters look jumbled up...I'm trying my best to give everybody a prominent space on screen.' After watching the movie, there is no scope for other characters," Mishti added.
# 실제 요약 : Kangana made fake promises to cast: 'Manikarnika' actress Mishti
# Extractive 요약 : Actress Mishti, who has featured in 'Manikarnika: The Queen of Jhansi', has said the film's co-director Kangana Ranaut made false promises to the cast.
#
#
# 원문 : The high-powered committee led by PM Narendra Modi to select the next CBI Director will meet again on February 1, Congress leader Mallikarjun Kharge has said. The panel consisting of Kharge and Chief Justice of India Ranjan Gogoi met on January 24, but the meeting ended "inconclusively" after Kharge cited lack of details in the list of 80 IPS officers.
# 실제 요약 : PM-led panel to meet on Friday to pick new CBI chief: Kharge
# Extractive 요약 : The high-powered committee led by PM Narendra Modi to select the next CBI Director will meet again on February 1, Congress leader Mallikarjun Kharge has said.
#
#
# 원문 : Nevada State Athletic Commission has banned MMA fighters Conor McGregor and Khabib Nurmagomedov for six months and nine months respectively over their roles in the mass brawl that occurred after their fight at UFC 229 last October. McGregor and Khabib have been fined $50,000 (Ã¢ÂÂ¹35 lakh) and $500,000 (Ã¢ÂÂ¹3.5 crore) respectively. The brawl occurred after Nurmagomedov confronted McGregor's teammate.
# 실제 요약 : McGregor fined Ã¢ÂÂ¹35 lakh, Khabib Ã¢ÂÂ¹3.5 crore for brawl; both banned
# Extractive 요약 : Nevada State Athletic Commission has banned MMA fighters Conor McGregor and Khabib Nurmagomedov for six months and nine months respectively over their roles in the mass brawl that occurred after their fight at UFC 229 last October.
#
#
# 원문 : Pakistan captain Sarfaraz Ahmed, who has been banned for four matches over racist remarks, took an apparent dig at his critics by sharing a video of a child reciting 'log hai na' poem on Twitter. "Pyaar karna hai to khud se kar...dushmani karne ke liye log hai na," the poem read. "This is how the world is," Sarfaraz wrote.
# 실제 요약 : Banned for 4 matches, Sarfaraz shares 'log hai na' poem for critics
# Extractive 요약 : Pakistan captain Sarfaraz Ahmed, who has been banned for four matches over racist remarks, took an apparent dig at his critics by sharing a video of a child reciting 'log hai na' poem on Twitter.
#
#
# 원문 : Banned cricketer Sreesanth has told Supreme Court he initially confessed to Delhi Police about his alleged involvement in 2013 IPL spot-fixing scandal to escape continuous police torture. Sreesanth further said the bookie tried dragging him into spot-fixing but he didn't fall for it. Citing Sreesanth not informing BCCI about fixing approach, the apex court said Sreesanth's conduct "wasn't good".
# 실제 요약 : Confessed to spot-fixing to escape police torture: Sreesanth to SC
# Extractive 요약 : Sreesanth further said the bookie tried dragging him into spot-fixing but he didn't fall for it.

# %% [markdown]
# ### 8) 회고

# %% [markdown]
# - 추출 요약 모델은 결과가 정확하게 나오지 않음을 확인
# - 추상 요약 모델은 결과가 나오지만 퀄리티가 높지 않음을 확인
